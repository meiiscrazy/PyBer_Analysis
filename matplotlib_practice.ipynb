# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
savings = [100,150,200,300,500,300,350,500,600,750,1000]
months = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct","Dec"]

# %%
plt.plot(months, savings)
plt.xlabel("Months")
plt.ylabel("Savings($)")
plt.title("Savings Account Results")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Line Graphs

# %%
# %matplotlib inline

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot with ax.plt()
ax = plt.axes()
ax.plot(x_axis, y_axis)

# %%
# Create the plot.
plt.plot(x_axis, y_axis)
plt.show()

# %%
# Create the plot.
plt.plot(x_axis, y_axis, marker="D", color="green", linewidth=2, label='Boston')
# Create labels for the x and y axes.
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45.
plt.ylim(0, 45)
# Create a title.
plt.title("PyBer Fare by Month")
# Add a grid.
plt.grid()
# Add the legend.
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Vertical & Horizontal Bar Graphs

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot
plt.bar(x_axis, y_axis)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <BarContainer object of 12 artists>

# %%
# Create the plot.
plt.barh(x_axis, y_axis, color="magenta", label='Boston')
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title.
plt.title("PyBer Fare by Month")
# Add the legend.
plt.legend()
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <img src="data:image/png;base64,..." width="432">
# <BarContainer object of 12 artists>

# %%
# Create the plot with ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color="cyan", label="Chicago")
plt.xlabel("Fare($)")
plt.ylabel("Month")
plt.title("PyBer Date by Month")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Scatter Plots

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.scatter(y_axis, x_axis, c="red", label="Chicago")
plt.xlabel("Fare($)")
plt.ylabel("Month")
plt.title("PyBer Date by Month")
plt.legend()
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.scatter(x_axis, y_axis, s=y_axis)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
y_axis_larger = []
for data in y_axis:
  y_axis_larger.append(data*3)

# %%
plt.scatter(x_axis, y_axis, s=y_axis_larger)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.scatter(x_axis, y_axis, s = [i * 3 for i in y_axis])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, color='skyblue', alpha=0.8, s=[i * 5 for i in y_axis], edgecolors='Black', linewidths=2, label='Boston')
plt.xlabel("Fare($)")
plt.ylabel("Month")
plt.title("PyBer Date by Month")
plt.xlim(0,50)
plt.legend()
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# # Pie Charts

# %%
# Pie Chart Demo
import matplotlib.pyplot as plt

# %%
categories = ["pants", "shirts", "outerwear", "pajamas", "underwear", "shoes"]
revenue = [25,15,5,20,10,25]

# %%
plt.pie(revenue)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
explode = [0, .1, 0, 0, 0, 0]

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%", explode=explode)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.pie(y_axis, labels=x_axis)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
plt.subplots(figsize=(8, 8))
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.pie(y_axis, explode=explode_values, labels=x_axis, autopct='%.1f%%')
# Out:
# <img src="data:image/png;base64,..." width="576">
# ([<matplotlib.patches.Wedge at 0x7ff7f5c312d0>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c31850>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c31f90>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c3c7d0>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c48150>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c48a50>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c55050>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c55810>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c3cf90>,
#   <matplotlib.patches.Wedge at 0x7ff7f5c48810>,
#   <matplotlib.patches.Wedge at 0x7ff7f5b9a750>,
#   <matplotlib.patches.Wedge at 0x7ff7f7124610>],
#  [Text(1.0940372721655667, 0.11437852557419124, 'Jan'),
#   Text(0.9905193092273052, 0.4784051609753622, 'Feb'),
#   Text(0.4998632656180861, 0.9798656620606842, 'Mar'),
#   Text(-0.32930826971286276, 1.0495504101750999, 'April'),
#   Text(-0.9306200792045569, 0.5864693241605263, 'May'),
#   Text(-1.0983369533258995, -0.06046434452452757, 'June'),
#   Text(-0.913463027456946, -0.9249785389235748, 'July'),
#   Text(-0.23338752507546193, -1.0749559354406817, 'Aug'),
#   Text(0.021097559209412746, -1.099797660024518, 'Sept'),
#   Text(0.460981299980763, -0.9987473359504124, 'Oct'),
#   Text(0.8868706338501641, -0.6507384104340302, 'Nov'),
#   Text(1.0760953148482877, -0.22807646384834376, 'Dec')],
#  [Text(0.5967476029993999, 0.06238828667683158, '3.3%'),
#   Text(0.5402832595785301, 0.2609482696229248, '7.7%'),
#   Text(0.27265269033713785, 0.5344721793058277, '13.0%'),
#   Text(-0.17962269257065241, 0.5724820419136908, '11.7%'),
#   Text(-0.5076109522933946, 0.3198923586330143, '10.7%'),
#   Text(-0.5990928836323088, -0.03298055155883321, '8.9%'),
#   Text(-0.562131093819659, -0.5692175624145076, '14.5%'),
#   Text(-0.1273022864047974, -0.5863396011494626, '3.5%'),
#   Text(0.011507759568770587, -0.5998896327406462, '3.9%'),
#   Text(0.2514443454440525, -0.5447712741547703, '9.2%'),
#   Text(0.4837476184637258, -0.35494822387310737, '6.9%'),
#   Text(0.5869610808263387, -0.12440534391727841, '6.6%')])

# %%
# Assign 12 colors, one for each month.
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8, 8))
plt.pie(y_axis,
    explode=explode_values,
    colors=colors,
    labels=x_axis,
    autopct='%.1f%%')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %%
fig, ax = plt.subplots(figsize=(8, 8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0.2, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
ax.pie(y_axis,labels=x_axis, explode=explode_values, autopct='%1.1f%%', colors=colors, shadow=True, startangle=98, counterclock=False)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">

# %% [markdown]
# # Ticks on Horizontal Bars

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
plt.barh(x_axis, y_axis)
plt.xticks(np.arange(0, 51, step=5.0))
plt.gca().invert_yaxis()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# Different method
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
from matplotlib.ticker import MultipleLocator
# Increase the size of the plot figure.
fig, ax = plt.subplots(figsize=(8, 8))
ax.barh(x_axis, y_axis)
ax.set_xticks(np.arange(0, 51, step=5.0))

# Create minor ticks at an increment of 1.
ax.xaxis.set_minor_locator(MultipleLocator(1))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="576">
